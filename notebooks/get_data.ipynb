# %%
import sys
sys.path.insert(0, '../')

# %%
from src.get_data import get_coinmetrics_data

# %%
file_path_metrics = '../data/static/metrics.txt'
file_path_assets = '../data/static/assets.txt'
days_before_today = 1
coinmetrics_data = (
    get_coinmetrics_data(
        days_before_today,
        file_path_metrics,
        file_path_assets
    )
)
# Out:
# 2023-12-11 17:52:57 INFO     API key not found. Using an empty string.
# c:\Users\belha\anaconda3\envs\belhakemCapital\lib\site-packages\pandas\core\dtypes\cast.py:1066: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# c:\Users\belha\anaconda3\envs\belhakemCapital\lib\site-packages\pandas\core\dtypes\cast.py:1091: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():

# %%
coinmetrics_data
# Out:
#   asset                      time  AdrActCnt  AdrBalCnt  \
# 0   btc 2023-12-10 00:00:00+00:00     848613   51207143
# 1   btc 2023-12-11 00:00:00+00:00       <NA>       <NA>
# 2   eth 2023-12-10 00:00:00+00:00     530418  110390694
# 3   eth 2023-12-11 00:00:00+00:00       <NA>       <NA>
# 4   xrp 2023-12-10 00:00:00+00:00      32045    4914837
# 5   xrp 2023-12-11 00:00:00+00:00       <NA>       <NA>
#
#    AssetEODCompletionTime  BlkCnt  BlkSizeMeanByte         CapAct1yrUSD  \
# 0              1702279363     140   1774205.828571  253091111379.015686
# 1                    <NA>    <NA>             <NA>                 <NA>
# 2              1702260320    7149    160807.439782  111579388674.268478
# 3                    <NA>    <NA>             <NA>                 <NA>
# 4              1702254805   22300             <NA>    26840424751.75367
# 5                    <NA>    <NA>             <NA>                 <NA>
#
# ...

# %%
from coinmetrics.api_client import get_utc_update_time
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from coinmetrics.api_client import get_utc_update_time
#
# ImportError: cannot import name 'get_utc_update_time' from 'coinmetrics.api_client' (c:\Users\belha\anaconda3\envs\belhakemCapital\lib\site-packages\coinmetrics\api_client.py)

# %%
import datetime
import pytz

def get_utc_update_string() -> str:
    utc_tz = pytz.UTC
    current_time_utc = datetime.datetime.now(tz=utc_tz)
    result_string = f"{current_time_utc.year}.{current_time_utc.month}.{current_time_utc.day}.{current_time_utc.hour}.{current_time_utc.minute}"
    return result_string

# %%
get_utc_update_string()
# Out:
# '2023.12.11.17.2'
